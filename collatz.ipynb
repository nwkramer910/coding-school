# %%
def find_odd_or_even(integer):
    if integer % 2 == 0:
        global number_type = 'odd'
    elif integer % 2 == 1:
        global number_type = 'even'
# Out:
#   Cell In[19], line 5
#     global number_type = 'odd'
#                        ^
# SyntaxError: invalid syntax

# %%
def collatz_v2(number):
    if number <= 1:
        print('Error: Number is less than or equal to 1. Please try again.')
        number = int(input('>'))
    else:
        print(f'Your number is {number}.')
    while number != 1:
        
        if number_type == 'odd':
            if number != 1:
                number = (3 * number) + 1
                print(number)
                continue
        elif find_odd_or_even(number) == 'even':           
            number = number // 2
            print(number)
            continue
        elif number == 1:
            print('You have reached the end of the loop.')
            break
        
collatz_v2(5)
# Out:
# Your number is 5.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 22
#      19             print('You have reached the end of the loop.')
#      20             break
# ---> 22 collatz_v2(5)
#
# Cell In[18], line 9, in collatz_v2(number)
#       7 while number != 1:
#       8     find_odd_or_even(number)
# ----> 9     if number_type == 'odd':
#      10         if number != 1:
#      11             number = (3 * number) + 1
#
# NameError: name 'number_type' is not defined

# %%
import random

def collatz(number):
    number = random.randint(2, 1000)
    print(number)
    if number <= 1:
        print('Error: Number is less than or equal to 1. Please try again.')
        number = int(input('>'))
    else:
        print(f'Your number is {number}.')
    while number != 1:
        if number % 2 == 1:
            if number != 1:
                number = (3 * number) + 1
                print('-' * number)
                continue
        elif number % 2 == 0:
            number = number // 2
            print('-' * number)
            continue
        elif number == 1:
            print('You have reached the end of the loop.')
            break

        
collatz(4)
# Out:
# 688
# Your number is 688.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------
# -------------------------------------------
# ----------------------------------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------
# ...
